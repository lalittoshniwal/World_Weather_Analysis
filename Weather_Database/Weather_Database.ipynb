# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import random
from citipy import citipy
import time
from datetime import datetime
import requests
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 714

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | mataura
# Processing Record 2 of Set 1 | pisco
# Processing Record 3 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 4 of Set 1 | comodoro rivadavia
# Processing Record 5 of Set 1 | los llanos de aridane
# Processing Record 6 of Set 1 | port elizabeth
# Processing Record 7 of Set 1 | poum
# Processing Record 8 of Set 1 | grand-santi
# Processing Record 9 of Set 1 | busselton
# Processing Record 10 of Set 1 | saint-philippe
# Processing Record 11 of Set 1 | barawe
# City not found. Skipping...
# Processing Record 12 of Set 1 | bluff
# Processing Record 13 of Set 1 | kahului
# Processing Record 14 of Set 1 | dwarka
# Processing Record 15 of Set 1 | aklavik
# Processing Record 16 of Set 1 | ushuaia
# Processing Record 17 of Set 1 | luderitz
# Processing Record 18 of Set 1 | bandarbeyla
# Processing Record 19 of Set 1 | umm ruwabah
# City not found. Skipping...
# Processing Record 20 of Set 1 | valentin gomez farias
# Processing Record 21 of Set 1 | vaini
# Processing Record 22 of Set 1 | nalut
# Processing Record 23 of Set 1 | urubicha
# Processing Record 24 of Set 1 | bredasdorp
# Processing Record 25 of Set 1 | lander
# Processing Record 26 of Set 1 | taoudenni
# Processing Record 27 of Set 1 | namibe
# Processing Record 28 of Set 1 | atuona
# Processing Record 29 of Set 1 | pevek
# Processing Record 30 of Set 1 | arraial do cabo
# Processing Record 31 of Set 1 | lavrentiya
# Processing Record 32 of Set 1 | geraldton
# Processing Record 33 of Set 1 | ahipara
# Processing Record 34 of Set 1 | shingu
# Processing Record 35 of Set 1 | ribeira brava
# Processing Record 36 of Set 1 | vanavara
# Processing Record 37 of Set 1 | punta arenas
# Processing Record 38 of Set 1 | hun
# Processing Record 39 of Set 1 | lebu
# Processing Record 40 of Set 1 | castro
# Processing Record 41 of Set 1 | olga
# Processing Record 42 of Set 1 | dikson
# Processing Record 43 of Set 1 | bluefields
# Processing Record 44 of Set 1 | nikolskoye
# Processing Record 45 of Set 1 | puerto escondido
# Processing Record 46 of Set 1 | albany
# Processing Record 47 of Set 1 | porto novo
# Processing Record 48 of Set 1 | felidhoo
# City not found. Skipping...
# Processing Record 49 of Set 1 | longyearbyen
# Processing Record 50 of Set 1 | menongue
# Processing Record 1 of Set 2 | gat
# Processing Record 2 of Set 2 | hasaki
# Processing Record 3 of Set 2 | lukovetskiy
# Processing Record 4 of Set 2 | hermanus
# Processing Record 5 of Set 2 | meadow lake
# Processing Record 6 of Set 2 | butaritari
# Processing Record 7 of Set 2 | fagersta
# Processing Record 8 of Set 2 | riachao
# Processing Record 9 of Set 2 | maceio
# Processing Record 10 of Set 2 | bambous virieux
# Processing Record 11 of Set 2 | zachagansk
# City not found. Skipping...
# Processing Record 12 of Set 2 | san quintin
# Processing Record 13 of Set 2 | rikitea
# Processing Record 14 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 15 of Set 2 | nelson bay
# Processing Record 16 of Set 2 | hithadhoo
# Processing Record 17 of Set 2 | san patricio
# Processing Record 18 of Set 2 | narsaq
# Processing Record 19 of Set 2 | biu
# Processing Record 20 of Set 2 | ngukurr
# City not found. Skipping...
# Processing Record 21 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 22 of Set 2 | ormond beach
# Processing Record 23 of Set 2 | port alfred
# Processing Record 24 of Set 2 | kapaa
# Processing Record 25 of Set 2 | new norfolk
# Processing Record 26 of Set 2 | luchegorsk
# Processing Record 27 of Set 2 | barrow
# Processing Record 28 of Set 2 | korla
# Processing Record 29 of Set 2 | jamestown
# Processing Record 30 of Set 2 | mahebourg
# Processing Record 31 of Set 2 | obo
# Processing Record 32 of Set 2 | cidreira
# Processing Record 33 of Set 2 | henties bay
# Processing Record 34 of Set 2 | dingle
# Processing Record 35 of Set 2 | beringovskiy
# Processing Record 36 of Set 2 | kenai
# Processing Record 37 of Set 2 | husavik
# Processing Record 38 of Set 2 | hobart
# Processing Record 39 of Set 2 | ferrol
# Processing Record 40 of Set 2 | chegdomyn
# Processing Record 41 of Set 2 | carlyle
# Processing Record 42 of Set 2 | baraut
# Processing Record 43 of Set 2 | kaitangata
# Processing Record 44 of Set 2 | grand centre
# City not found. Skipping...
# Processing Record 45 of Set 2 | alofi
# Processing Record 46 of Set 2 | tuktoyaktuk
# Processing Record 47 of Set 2 | pinega
# Processing Record 48 of Set 2 | mosquera
# Processing Record 49 of Set 2 | victoria
# Processing Record 50 of Set 2 | east london
# Processing Record 1 of Set 3 | matara
# Processing Record 2 of Set 3 | tiznit
# Processing Record 3 of Set 3 | mekhe
# Processing Record 4 of Set 3 | yar-sale
# Processing Record 5 of Set 3 | ponta delgada
# Processing Record 6 of Set 3 | vardo
# Processing Record 7 of Set 3 | muncar
# Processing Record 8 of Set 3 | samarai
# Processing Record 9 of Set 3 | glendive
# Processing Record 10 of Set 3 | hofn
# Processing Record 11 of Set 3 | huilong
# Processing Record 12 of Set 3 | sovetskiy
# Processing Record 13 of Set 3 | tiksi
# Processing Record 14 of Set 3 | chiang khong
# Processing Record 15 of Set 3 | tautira
# Processing Record 16 of Set 3 | naftah
# City not found. Skipping...
# Processing Record 17 of Set 3 | cabo san lucas
# Processing Record 18 of Set 3 | yellowknife
# Processing Record 19 of Set 3 | buariki
# City not found. Skipping...
# Processing Record 20 of Set 3 | napanee
# Processing Record 21 of Set 3 | bethel
# Processing Record 22 of Set 3 | cururupu
# Processing Record 23 of Set 3 | antalaha
# Processing Record 24 of Set 3 | biak
# Processing Record 25 of Set 3 | chokurdakh
# Processing Record 26 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 27 of Set 3 | muros
# Processing Record 28 of Set 3 | aquiraz
# Processing Record 29 of Set 3 | saskylakh
# Processing Record 30 of Set 3 | clyde river
# Processing Record 31 of Set 3 | kodiak
# Processing Record 32 of Set 3 | katangli
# Processing Record 33 of Set 3 | rovaniemi
# Processing Record 34 of Set 3 | lubbock
# Processing Record 35 of Set 3 | presidencia roque saenz pena
# Processing Record 36 of Set 3 | evanston
# Processing Record 37 of Set 3 | sept-iles
# Processing Record 38 of Set 3 | flagstaff
# Processing Record 39 of Set 3 | mount isa
# Processing Record 40 of Set 3 | imbituba
# Processing Record 41 of Set 3 | masvingo
# Processing Record 42 of Set 3 | saint pete beach
# Processing Record 43 of Set 3 | meulaboh
# Processing Record 44 of Set 3 | hilo
# Processing Record 45 of Set 3 | matamoros
# Processing Record 46 of Set 3 | cape town
# Processing Record 47 of Set 3 | bairiki
# Processing Record 48 of Set 3 | sorong
# Processing Record 49 of Set 3 | berlevag
# Processing Record 50 of Set 3 | sioux lookout
# Processing Record 1 of Set 4 | raudeberg
# Processing Record 2 of Set 4 | kishtwar
# Processing Record 3 of Set 4 | avarua
# Processing Record 4 of Set 4 | nuuk
# Processing Record 5 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 6 of Set 4 | taolanaro
# City not found. Skipping...
# Processing Record 7 of Set 4 | brus laguna
# Processing Record 8 of Set 4 | lagoa
# Processing Record 9 of Set 4 | ponta do sol
# Processing Record 10 of Set 4 | sawakin
# Processing Record 11 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 12 of Set 4 | urusha
# Processing Record 13 of Set 4 | santa lucia
# Processing Record 14 of Set 4 | nieuw amsterdam
# Processing Record 15 of Set 4 | puerto ayora
# Processing Record 16 of Set 4 | mar del plata
# Processing Record 17 of Set 4 | ofunato
# Processing Record 18 of Set 4 | bonfim
# Processing Record 19 of Set 4 | klaksvik
# Processing Record 20 of Set 4 | lazaro cardenas
# Processing Record 21 of Set 4 | paranhos
# Processing Record 22 of Set 4 | shimoda
# Processing Record 23 of Set 4 | khasan
# Processing Record 24 of Set 4 | torbay
# Processing Record 25 of Set 4 | gazli
# Processing Record 26 of Set 4 | nanortalik
# Processing Record 27 of Set 4 | severo-kurilsk
# Processing Record 28 of Set 4 | nizhniy tsasuchey
# Processing Record 29 of Set 4 | ugoofaaru
# Processing Record 30 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 31 of Set 4 | kysyl-syr
# Processing Record 32 of Set 4 | songjianghe
# Processing Record 33 of Set 4 | georgetown
# Processing Record 34 of Set 4 | cockburn town
# Processing Record 35 of Set 4 | coihaique
# Processing Record 36 of Set 4 | limon
# Processing Record 37 of Set 4 | faanui
# Processing Record 38 of Set 4 | orumiyeh
# Processing Record 39 of Set 4 | marsabit
# Processing Record 40 of Set 4 | karaul
# City not found. Skipping...
# Processing Record 41 of Set 4 | sao felix do xingu
# Processing Record 42 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 43 of Set 4 | ancud
# Processing Record 44 of Set 4 | lima
# Processing Record 45 of Set 4 | esperance
# Processing Record 46 of Set 4 | codrington
# Processing Record 47 of Set 4 | santa maria
# Processing Record 48 of Set 4 | analipsis
# Processing Record 49 of Set 4 | phulabani
# Processing Record 50 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 1 of Set 5 | paradwip
# City not found. Skipping...
# Processing Record 2 of Set 5 | thompson
# Processing Record 3 of Set 5 | ilulissat
# Processing Record 4 of Set 5 | navirai
# Processing Record 5 of Set 5 | hovd
# Processing Record 6 of Set 5 | port moresby
# Processing Record 7 of Set 5 | rapid valley
# Processing Record 8 of Set 5 | pangai
# Processing Record 9 of Set 5 | alcains
# Processing Record 10 of Set 5 | bahia blanca
# Processing Record 11 of Set 5 | bani walid
# Processing Record 12 of Set 5 | kavieng
# Processing Record 13 of Set 5 | malinyi
# Processing Record 14 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 15 of Set 5 | baghdad
# Processing Record 16 of Set 5 | buraydah
# Processing Record 17 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 18 of Set 5 | portland
# Processing Record 19 of Set 5 | shelabolikha
# Processing Record 20 of Set 5 | loja
# Processing Record 21 of Set 5 | goundam
# Processing Record 22 of Set 5 | ostrovnoy
# Processing Record 23 of Set 5 | cortez
# Processing Record 24 of Set 5 | oussouye
# Processing Record 25 of Set 5 | namatanai
# Processing Record 26 of Set 5 | moron
# Processing Record 27 of Set 5 | garowe
# Processing Record 28 of Set 5 | malanville
# Processing Record 29 of Set 5 | constitucion
# Processing Record 30 of Set 5 | panama city
# Processing Record 31 of Set 5 | akdepe
# Processing Record 32 of Set 5 | shagonar
# Processing Record 33 of Set 5 | chuy
# Processing Record 34 of Set 5 | kerman
# Processing Record 35 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 36 of Set 5 | aqtobe
# Processing Record 37 of Set 5 | inirida
# Processing Record 38 of Set 5 | the valley
# Processing Record 39 of Set 5 | leningradskiy
# Processing Record 40 of Set 5 | asfi
# Processing Record 41 of Set 5 | ambanja
# Processing Record 42 of Set 5 | makakilo city
# Processing Record 43 of Set 5 | port lincoln
# Processing Record 44 of Set 5 | shanghai
# Processing Record 45 of Set 5 | katsuura
# Processing Record 46 of Set 5 | zhigansk
# Processing Record 47 of Set 5 | guerrero negro
# Processing Record 48 of Set 5 | provideniya
# Processing Record 49 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 50 of Set 5 | casa nova
# Processing Record 1 of Set 6 | sitka
# Processing Record 2 of Set 6 | sirnak
# Processing Record 3 of Set 6 | riverton
# Processing Record 4 of Set 6 | vila velha
# Processing Record 5 of Set 6 | salta
# Processing Record 6 of Set 6 | araouane
# Processing Record 7 of Set 6 | saint-louis
# Processing Record 8 of Set 6 | upernavik
# Processing Record 9 of Set 6 | tombouctou
# Processing Record 10 of Set 6 | bolungarvik
# City not found. Skipping...
# Processing Record 11 of Set 6 | nemuro
# Processing Record 12 of Set 6 | haines junction
# Processing Record 13 of Set 6 | quatre cocos
# Processing Record 14 of Set 6 | tawkar
# City not found. Skipping...
# Processing Record 15 of Set 6 | la rioja
# Processing Record 16 of Set 6 | shache
# Processing Record 17 of Set 6 | martapura
# Processing Record 18 of Set 6 | mandalgovi
# Processing Record 19 of Set 6 | mayumba
# Processing Record 20 of Set 6 | puerto del rosario
# Processing Record 21 of Set 6 | bulgan
# Processing Record 22 of Set 6 | skuodas
# Processing Record 23 of Set 6 | maloshuyka
# City not found. Skipping...
# Processing Record 24 of Set 6 | bandar
# Processing Record 25 of Set 6 | itaqui
# Processing Record 26 of Set 6 | cassilandia
# Processing Record 27 of Set 6 | waipawa
# Processing Record 28 of Set 6 | ukiah
# Processing Record 29 of Set 6 | port hedland
# Processing Record 30 of Set 6 | kruisfontein
# Processing Record 31 of Set 6 | saint george
# Processing Record 32 of Set 6 | qaqortoq
# Processing Record 33 of Set 6 | qaanaaq
# Processing Record 34 of Set 6 | avera
# Processing Record 35 of Set 6 | baykit
# Processing Record 36 of Set 6 | talnakh
# Processing Record 37 of Set 6 | norman wells
# Processing Record 38 of Set 6 | sesheke
# Processing Record 39 of Set 6 | havelock
# Processing Record 40 of Set 6 | labrea
# Processing Record 41 of Set 6 | tairua
# Processing Record 42 of Set 6 | antofagasta
# Processing Record 43 of Set 6 | matay
# Processing Record 44 of Set 6 | thinadhoo
# Processing Record 45 of Set 6 | berbera
# Processing Record 46 of Set 6 | roald
# Processing Record 47 of Set 6 | sulangan
# Processing Record 48 of Set 6 | guiratinga
# Processing Record 49 of Set 6 | senneterre
# Processing Record 50 of Set 6 | santa clara
# Processing Record 1 of Set 7 | port blair
# Processing Record 2 of Set 7 | pozo colorado
# Processing Record 3 of Set 7 | puerto ayacucho
# Processing Record 4 of Set 7 | tuatapere
# Processing Record 5 of Set 7 | awbari
# Processing Record 6 of Set 7 | necochea
# Processing Record 7 of Set 7 | bosaso
# Processing Record 8 of Set 7 | tura
# Processing Record 9 of Set 7 | warrington
# Processing Record 10 of Set 7 | lima duarte
# Processing Record 11 of Set 7 | kamenskoye
# City not found. Skipping...
# Processing Record 12 of Set 7 | kutina
# Processing Record 13 of Set 7 | bonaventure
# Processing Record 14 of Set 7 | airai
# Processing Record 15 of Set 7 | ijaki
# City not found. Skipping...
# Processing Record 16 of Set 7 | ketchikan
# Processing Record 17 of Set 7 | bukama
# Processing Record 18 of Set 7 | kaeo
# Processing Record 19 of Set 7 | tulum
# Processing Record 20 of Set 7 | carnarvon
# Processing Record 21 of Set 7 | oksfjord
# Processing Record 22 of Set 7 | te anau
# Processing Record 23 of Set 7 | saint-georges
# Processing Record 24 of Set 7 | port hardy
# Processing Record 25 of Set 7 | college
# Processing Record 26 of Set 7 | cervo
# Processing Record 27 of Set 7 | fairbanks
# Processing Record 28 of Set 7 | takoradi
# Processing Record 29 of Set 7 | pakwach
# City not found. Skipping...
# Processing Record 30 of Set 7 | tabuk
# Processing Record 31 of Set 7 | saint-pierre
# Processing Record 32 of Set 7 | bow island
# Processing Record 33 of Set 7 | rizhao
# Processing Record 34 of Set 7 | ribeira grande
# Processing Record 35 of Set 7 | ajdabiya
# Processing Record 36 of Set 7 | uglovskoye
# Processing Record 37 of Set 7 | houston
# Processing Record 38 of Set 7 | west lafayette
# Processing Record 39 of Set 7 | bargal
# City not found. Skipping...
# Processing Record 40 of Set 7 | belaya gora
# Processing Record 41 of Set 7 | trinidad
# Processing Record 42 of Set 7 | xining
# Processing Record 43 of Set 7 | inuvik
# Processing Record 44 of Set 7 | mount gambier
# Processing Record 45 of Set 7 | krasnyy yar
# Processing Record 46 of Set 7 | sao filipe
# Processing Record 47 of Set 7 | iturama
# Processing Record 48 of Set 7 | san pedro
# Processing Record 49 of Set 7 | lorengau
# Processing Record 50 of Set 7 | deputatskiy
# Processing Record 1 of Set 8 | margate
# Processing Record 2 of Set 8 | kralendijk
# Processing Record 3 of Set 8 | rawson
# Processing Record 4 of Set 8 | ust-tarka
# Processing Record 5 of Set 8 | deep river
# Processing Record 6 of Set 8 | beloha
# Processing Record 7 of Set 8 | menton
# Processing Record 8 of Set 8 | faya
# Processing Record 9 of Set 8 | salalah
# Processing Record 10 of Set 8 | saryg-sep
# Processing Record 11 of Set 8 | palmer
# Processing Record 12 of Set 8 | salinopolis
# Processing Record 13 of Set 8 | okhotsk
# Processing Record 14 of Set 8 | emborion
# Processing Record 15 of Set 8 | tabiauea
# City not found. Skipping...
# Processing Record 16 of Set 8 | puerto quijarro
# Processing Record 17 of Set 8 | eureka
# Processing Record 18 of Set 8 | oranjemund
# Processing Record 19 of Set 8 | bilma
# Processing Record 20 of Set 8 | khatanga
# Processing Record 21 of Set 8 | ephrata
# Processing Record 22 of Set 8 | fernie
# Processing Record 23 of Set 8 | bagdarin
# Processing Record 24 of Set 8 | westport
# Processing Record 25 of Set 8 | tianpeng
# Processing Record 26 of Set 8 | roma
# Processing Record 27 of Set 8 | manicore
# Processing Record 28 of Set 8 | vila franca do campo
# Processing Record 29 of Set 8 | waingapu
# Processing Record 30 of Set 8 | barra
# Processing Record 31 of Set 8 | bodden town
# Processing Record 32 of Set 8 | marigot
# Processing Record 33 of Set 8 | cusuna
# Processing Record 34 of Set 8 | tasiilaq
# Processing Record 35 of Set 8 | iquique
# Processing Record 36 of Set 8 | pangnirtung
# Processing Record 37 of Set 8 | mitchell
# Processing Record 38 of Set 8 | lucatan
# City not found. Skipping...
# Processing Record 39 of Set 8 | murray bridge
# Processing Record 40 of Set 8 | wembley
# Processing Record 41 of Set 8 | fortuna
# Processing Record 42 of Set 8 | minab
# Processing Record 43 of Set 8 | adrar
# Processing Record 44 of Set 8 | flinders
# Processing Record 45 of Set 8 | valdosta
# Processing Record 46 of Set 8 | ouadda
# Processing Record 47 of Set 8 | santa fe
# Processing Record 48 of Set 8 | kuala terengganu
# Processing Record 49 of Set 8 | afzalgarh
# Processing Record 50 of Set 8 | cherskiy
# Processing Record 1 of Set 9 | sao miguel do iguacu
# Processing Record 2 of Set 9 | pirenopolis
# Processing Record 3 of Set 9 | yialos
# City not found. Skipping...
# Processing Record 4 of Set 9 | calmar
# Processing Record 5 of Set 9 | kirgiz-miyaki
# Processing Record 6 of Set 9 | beni suef
# Processing Record 7 of Set 9 | ankang
# Processing Record 8 of Set 9 | anchorage
# Processing Record 9 of Set 9 | sibu
# Processing Record 10 of Set 9 | chunoyar
# Processing Record 11 of Set 9 | puyang
# Processing Record 12 of Set 9 | half moon bay
# Processing Record 13 of Set 9 | arman
# Processing Record 14 of Set 9 | karratha
# Processing Record 15 of Set 9 | yulara
# Processing Record 16 of Set 9 | nguiu
# City not found. Skipping...
# Processing Record 17 of Set 9 | leh
# Processing Record 18 of Set 9 | bhatkal
# Processing Record 19 of Set 9 | inongo
# Processing Record 20 of Set 9 | erenhot
# Processing Record 21 of Set 9 | champerico
# Processing Record 22 of Set 9 | saint-marc-des-carrieres
# Processing Record 23 of Set 9 | teya
# Processing Record 24 of Set 9 | gladstone
# Processing Record 25 of Set 9 | jequie
# Processing Record 26 of Set 9 | wewak
# Processing Record 27 of Set 9 | ambunti
# Processing Record 28 of Set 9 | sarakhs
# Processing Record 29 of Set 9 | espanola
# Processing Record 30 of Set 9 | mayo
# Processing Record 31 of Set 9 | severnyy
# Processing Record 32 of Set 9 | bar harbor
# Processing Record 33 of Set 9 | grinnell
# Processing Record 34 of Set 9 | russell
# Processing Record 35 of Set 9 | marzuq
# Processing Record 36 of Set 9 | novoagansk
# Processing Record 37 of Set 9 | tilichiki
# Processing Record 38 of Set 9 | utiroa
# City not found. Skipping...
# Processing Record 39 of Set 9 | umtata
# Processing Record 40 of Set 9 | kauhajoki
# Processing Record 41 of Set 9 | jiblah
# Processing Record 42 of Set 9 | neepawa
# Processing Record 43 of Set 9 | ust-maya
# Processing Record 44 of Set 9 | egvekinot
# Processing Record 45 of Set 9 | basco
# Processing Record 46 of Set 9 | lenger
# Processing Record 47 of Set 9 | chumikan
# Processing Record 48 of Set 9 | katha
# City not found. Skipping...
# Processing Record 49 of Set 9 | abilene
# Processing Record 50 of Set 9 | luena
# Processing Record 1 of Set 10 | abu samrah
# Processing Record 2 of Set 10 | aginskoye
# Processing Record 3 of Set 10 | anshun
# Processing Record 4 of Set 10 | igrim
# Processing Record 5 of Set 10 | coquimbo
# Processing Record 6 of Set 10 | sindor
# Processing Record 7 of Set 10 | souillac
# Processing Record 8 of Set 10 | quang ngai
# Processing Record 9 of Set 10 | ambad
# Processing Record 10 of Set 10 | alta floresta
# Processing Record 11 of Set 10 | kuminskiy
# Processing Record 12 of Set 10 | gurgan
# City not found. Skipping...
# Processing Record 13 of Set 10 | hailun
# Processing Record 14 of Set 10 | upington
# Processing Record 15 of Set 10 | ig
# City not found. Skipping...
# Processing Record 16 of Set 10 | limbang
# Processing Record 17 of Set 10 | kalemie
# Processing Record 18 of Set 10 | arrifes
# Processing Record 19 of Set 10 | vao
# Processing Record 20 of Set 10 | hutchinson
# Processing Record 21 of Set 10 | la orilla
# Processing Record 22 of Set 10 | jiddah
# City not found. Skipping...
# Processing Record 23 of Set 10 | stoyba
# City not found. Skipping...
# Processing Record 24 of Set 10 | kavaratti
# Processing Record 25 of Set 10 | creel
# Processing Record 26 of Set 10 | puerto narino
# Processing Record 27 of Set 10 | mantua
# Processing Record 28 of Set 10 | vale
# Processing Record 29 of Set 10 | warrnambool
# Processing Record 30 of Set 10 | venado
# Processing Record 31 of Set 10 | babanusah
# City not found. Skipping...
# Processing Record 32 of Set 10 | dingzhou
# Processing Record 33 of Set 10 | gamba
# Processing Record 34 of Set 10 | olafsvik
# Processing Record 35 of Set 10 | delta del tigre
# Processing Record 36 of Set 10 | muana
# Processing Record 37 of Set 10 | meyungs
# City not found. Skipping...
# Processing Record 38 of Set 10 | vysokogornyy
# Processing Record 39 of Set 10 | praia da vitoria
# Processing Record 40 of Set 10 | tevaitoa
# Processing Record 41 of Set 10 | ulaanbaatar
# Processing Record 42 of Set 10 | peleduy
# Processing Record 43 of Set 10 | barcelos
# Processing Record 44 of Set 10 | mwene-ditu
# Processing Record 45 of Set 10 | la ronge
# Processing Record 46 of Set 10 | biloela
# Processing Record 47 of Set 10 | yuzhno-kurilsk
# Processing Record 48 of Set 10 | muskegon
# Processing Record 49 of Set 10 | olinda
# Processing Record 50 of Set 10 | celestun
# Processing Record 1 of Set 11 | filingue
# Processing Record 2 of Set 11 | plettenberg bay
# Processing Record 3 of Set 11 | iztapa
# Processing Record 4 of Set 11 | waitati
# Processing Record 5 of Set 11 | penarroya-pueblonuevo
# Processing Record 6 of Set 11 | brattvag
# Processing Record 7 of Set 11 | jilib
# Processing Record 8 of Set 11 | villa maria
# Processing Record 9 of Set 11 | novyy urengoy
# Processing Record 10 of Set 11 | ondangwa
# Processing Record 11 of Set 11 | smiltene
# Processing Record 12 of Set 11 | sur
# Processing Record 13 of Set 11 | peniche
# Processing Record 14 of Set 11 | ballina
# Processing Record 15 of Set 11 | telimele
# Processing Record 16 of Set 11 | padang
# Processing Record 17 of Set 11 | konza
# Processing Record 18 of Set 11 | vasterhaninge
# Processing Record 19 of Set 11 | valparaiso
# Processing Record 20 of Set 11 | halalo
# City not found. Skipping...
# Processing Record 21 of Set 11 | mata de sao joao
# Processing Record 22 of Set 11 | nouakchott
# Processing Record 23 of Set 11 | iquitos
# Processing Record 24 of Set 11 | havre-saint-pierre
# Processing Record 25 of Set 11 | micheweni
# Processing Record 26 of Set 11 | churapcha
# Processing Record 27 of Set 11 | buala
# Processing Record 28 of Set 11 | san angelo
# Processing Record 29 of Set 11 | sao domingos
# Processing Record 30 of Set 11 | miri
# Processing Record 31 of Set 11 | isangel
# Processing Record 32 of Set 11 | varca
# Processing Record 33 of Set 11 | sechura
# Processing Record 34 of Set 11 | del rio
# Processing Record 35 of Set 11 | scarborough
# Processing Record 36 of Set 11 | tocopilla
# Processing Record 37 of Set 11 | hailar
# Processing Record 38 of Set 11 | astana
# Processing Record 39 of Set 11 | megion
# Processing Record 40 of Set 11 | iqaluit
# Processing Record 41 of Set 11 | tabou
# Processing Record 42 of Set 11 | de aar
# Processing Record 43 of Set 11 | groningen
# Processing Record 44 of Set 11 | nicoya
# Processing Record 45 of Set 11 | viedma
# Processing Record 46 of Set 11 | almeria
# Processing Record 47 of Set 11 | dunedin
# Processing Record 48 of Set 11 | suzaka
# Processing Record 49 of Set 11 | haysyn
# Processing Record 50 of Set 11 | jungapeo
# Processing Record 1 of Set 12 | florianopolis
# Processing Record 2 of Set 12 | sabang
# Processing Record 3 of Set 12 | barentsburg
# City not found. Skipping...
# Processing Record 4 of Set 12 | coahuayana
# Processing Record 5 of Set 12 | chengde
# Processing Record 6 of Set 12 | boralday
# Processing Record 7 of Set 12 | seminole
# Processing Record 8 of Set 12 | sikasso
# Processing Record 9 of Set 12 | bontang
# Processing Record 10 of Set 12 | santa isabel do rio negro
# Processing Record 11 of Set 12 | lerwick
# Processing Record 12 of Set 12 | sayalgudi
# City not found. Skipping...
# Processing Record 13 of Set 12 | quijingue
# Processing Record 14 of Set 12 | balabac
# Processing Record 15 of Set 12 | pacific grove
# Processing Record 16 of Set 12 | kargopol
# Processing Record 17 of Set 12 | anastacio
# Processing Record 18 of Set 12 | crossville
# Processing Record 19 of Set 12 | hakui
# Processing Record 20 of Set 12 | rawannawi
# City not found. Skipping...
# Processing Record 21 of Set 12 | port macquarie
# Processing Record 22 of Set 12 | acapulco
# Processing Record 23 of Set 12 | kirando
# Processing Record 24 of Set 12 | yershov
# Processing Record 25 of Set 12 | gornozavodsk
# Processing Record 26 of Set 12 | ganzhou
# Processing Record 27 of Set 12 | bengkulu
# Processing Record 28 of Set 12 | isiolo
# Processing Record 29 of Set 12 | caucaia
# Processing Record 30 of Set 12 | touros
# Processing Record 31 of Set 12 | boyolangu
# Processing Record 32 of Set 12 | ruzomberok
# Processing Record 33 of Set 12 | port-cartier
# Processing Record 34 of Set 12 | chernyshevskiy
# Processing Record 35 of Set 12 | saint anthony
# Processing Record 36 of Set 12 | kholodnyy
# Processing Record 37 of Set 12 | jakar
# Processing Record 38 of Set 12 | alamosa
# Processing Record 39 of Set 12 | sebastian
# Processing Record 40 of Set 12 | dalvik
# Processing Record 41 of Set 12 | saint-augustin
# Processing Record 42 of Set 12 | lengshuijiang
# Processing Record 43 of Set 12 | honiara
# Processing Record 44 of Set 12 | upata
# Processing Record 45 of Set 12 | bambamarca
# Processing Record 46 of Set 12 | alekseyevsk
# Processing Record 47 of Set 12 | greymouth
# Processing Record 48 of Set 12 | wajir
# Processing Record 49 of Set 12 | nakonde
# Processing Record 50 of Set 12 | dudinka
# Processing Record 1 of Set 13 | vila do maio
# Processing Record 2 of Set 13 | togur
# Processing Record 3 of Set 13 | querfurt
# Processing Record 4 of Set 13 | rungata
# City not found. Skipping...
# Processing Record 5 of Set 13 | birao
# Processing Record 6 of Set 13 | nouadhibou
# Processing Record 7 of Set 13 | caravelas
# Processing Record 8 of Set 13 | bur gabo
# City not found. Skipping...
# Processing Record 9 of Set 13 | bose
# Processing Record 10 of Set 13 | sarankhola
# Processing Record 11 of Set 13 | missungwi
# Processing Record 12 of Set 13 | cabra
# Processing Record 13 of Set 13 | tandil
# Processing Record 14 of Set 13 | lashio
# Processing Record 15 of Set 13 | novobirilyussy
# Processing Record 16 of Set 13 | saldanha
# Processing Record 17 of Set 13 | urumqi
# Processing Record 18 of Set 13 | san ramon
# Processing Record 19 of Set 13 | san jeronimo
# Processing Record 20 of Set 13 | lasa
# Processing Record 21 of Set 13 | saint-paul
# Processing Record 22 of Set 13 | toamasina
# Processing Record 23 of Set 13 | hay river
# Processing Record 24 of Set 13 | yaguajay
# Processing Record 25 of Set 13 | griffith
# Processing Record 26 of Set 13 | umea
# Processing Record 27 of Set 13 | potgietersrus
# City not found. Skipping...
# Processing Record 28 of Set 13 | coracao de jesus
# Processing Record 29 of Set 13 | uncia
# Processing Record 30 of Set 13 | hamilton
# Processing Record 31 of Set 13 | angra
# City not found. Skipping...
# Processing Record 32 of Set 13 | bombay
# Processing Record 33 of Set 13 | jalu
# Processing Record 34 of Set 13 | ningyang
# Processing Record 35 of Set 13 | lufilufi
# Processing Record 36 of Set 13 | todos santos
# Processing Record 37 of Set 13 | omsukchan
# Processing Record 38 of Set 13 | chazuta
# Processing Record 39 of Set 13 | gadwal
# Processing Record 40 of Set 13 | aldergrove
# Processing Record 41 of Set 13 | toliary
# City not found. Skipping...
# Processing Record 42 of Set 13 | mocambique
# City not found. Skipping...
# Processing Record 43 of Set 13 | camapua
# Processing Record 44 of Set 13 | manta
# Processing Record 45 of Set 13 | tocache
# Processing Record 46 of Set 13 | nishihara
# Processing Record 47 of Set 13 | lamu
# Processing Record 48 of Set 13 | mul
# Processing Record 49 of Set 13 | ha tinh
# Processing Record 50 of Set 13 | poso
# Processing Record 1 of Set 14 | auki
# Processing Record 2 of Set 14 | san cristobal
# Processing Record 3 of Set 14 | laguna
# Processing Record 4 of Set 14 | saint-ambroise
# Processing Record 5 of Set 14 | dryden
# Processing Record 6 of Set 14 | bogalusa
# Processing Record 7 of Set 14 | lata
# Processing Record 8 of Set 14 | moree
# Processing Record 9 of Set 14 | pitimbu
# Processing Record 10 of Set 14 | amapa
# Processing Record 11 of Set 14 | puerto plata
# Processing Record 12 of Set 14 | casale monferrato
# Processing Record 13 of Set 14 | norheimsund
# Processing Record 14 of Set 14 | camacha
# Processing Record 15 of Set 14 | maslovka
# Processing Record 16 of Set 14 | tera
# Processing Record 17 of Set 14 | mancio lima
# Processing Record 18 of Set 14 | jiayuguan
# Processing Record 19 of Set 14 | tome-acu
# City not found. Skipping...
# Processing Record 20 of Set 14 | lompoc
# Processing Record 21 of Set 14 | vizantea
# City not found. Skipping...
# Processing Record 22 of Set 14 | campo formoso
# Processing Record 23 of Set 14 | rehoboth
# Processing Record 24 of Set 14 | kawalu
# Processing Record 25 of Set 14 | pandan
# Processing Record 26 of Set 14 | nueva imperial
# Processing Record 27 of Set 14 | yurginskoye
# Processing Record 28 of Set 14 | hwange
# Processing Record 29 of Set 14 | bani
# Processing Record 30 of Set 14 | tumbagaan
# Processing Record 31 of Set 14 | yumen
# Processing Record 32 of Set 14 | mersing
# Processing Record 33 of Set 14 | tamayo
# Processing Record 34 of Set 14 | pergamino
# Processing Record 35 of Set 14 | puerto madryn
# Processing Record 36 of Set 14 | petropavlovsk-kamchatskiy
# Processing Record 37 of Set 14 | bay roberts
# Processing Record 38 of Set 14 | kieta
# Processing Record 39 of Set 14 | damietta
# Processing Record 40 of Set 14 | talah
# City not found. Skipping...
# Processing Record 41 of Set 14 | katima mulilo
# Processing Record 42 of Set 14 | morondava
# Processing Record 43 of Set 14 | punta alta
# Processing Record 44 of Set 14 | coos bay
# Processing Record 45 of Set 14 | thunder bay
# Processing Record 46 of Set 14 | moussoro
# Processing Record 47 of Set 14 | adeje
# Processing Record 48 of Set 14 | bah
# Processing Record 49 of Set 14 | talavera de la reina
# Processing Record 50 of Set 14 | ferme-neuve
# Processing Record 1 of Set 15 | koslan
# Processing Record 2 of Set 15 | karangampel
# Processing Record 3 of Set 15 | crab hill
# City not found. Skipping...
# Processing Record 4 of Set 15 | kazalinsk
# City not found. Skipping...
# Processing Record 5 of Set 15 | wanning
# Processing Record 6 of Set 15 | cairns
# Processing Record 7 of Set 15 | tasbuget
# City not found. Skipping...
# Processing Record 8 of Set 15 | solnechnyy
# Processing Record 9 of Set 15 | prince rupert
# Processing Record 10 of Set 15 | ornskoldsvik
# Processing Record 11 of Set 15 | ujjain
# Processing Record 12 of Set 15 | sinop
# Processing Record 13 of Set 15 | kurilsk
# Processing Record 14 of Set 15 | huarmey
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.rename(columns = {'Description':'Current Description'}, inplace = True)
city_data_df.head(10)
# Out:
#                     City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0                Mataura -46.1927  168.8643     66.47        63          94
# 1                  Pisco -13.7000  -76.2167     66.25        77           0
# 2     Comodoro Rivadavia -45.8667  -67.5000     35.46        64           0
# 3  Los Llanos De Aridane  28.6585  -17.9182     60.55        92          75
# 4         Port Elizabeth -33.9180   25.5701     61.32        71          51
# 5                   Poum -20.2333  164.0167     77.56        70          41
# 6            Grand-Santi   4.2500  -54.3833     73.42        98          94
# 7              Busselton -33.6500  115.3333     64.99        57           0
# 8         Saint-Philippe -21.3585   55.7679     74.79        83          44
# 9                  Bluff -46.6000  168.3333     66.79        72          98
#
#    Wind Speed Country Current Description
# 0        2.77      NZ     overcast clouds
# 1        8.05      PE           clear sky
# 2        4.61      AR           clear sky
# 3       11.50      ES       broken clouds
# 4        3.00      ZA       broken clouds
# 5        9.53      NC    scattered clouds
# 6        3.24      GF     overcast clouds
# 7        2.98      AU           clear sky
# 8       14.74      RE    scattered clouds
# 9        5.17      NZ     overcast clouds

# %%
#reorder columns
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head()
# Out:
#                     City Country      Lat       Lng  Max Temp  Humidity  \
# 0                Mataura      NZ -46.1927  168.8643     66.47        63
# 1                  Pisco      PE -13.7000  -76.2167     66.25        77
# 2     Comodoro Rivadavia      AR -45.8667  -67.5000     35.46        64
# 3  Los Llanos De Aridane      ES  28.6585  -17.9182     60.55        92
# 4         Port Elizabeth      ZA -33.9180   25.5701     61.32        71
#
#    Cloudiness  Wind Speed Current Description
# 0          94        2.77     overcast clouds
# 1           0        8.05           clear sky
# 2           0        4.61           clear sky
# 3          75       11.50       broken clouds
# 4          51        3.00       broken clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
